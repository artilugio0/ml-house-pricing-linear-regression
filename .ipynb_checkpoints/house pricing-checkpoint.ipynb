# %% [markdown]
# # House pricing ML model project
#
# This project is based on chapter 2 of the book "Hands On Machine Learning with Scikit-Lear, Keras and Tensorflow".
#
# The purpose of the project is to create a model capable of predicting house prices for each district in California based on the California sensus dataset.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Downloading the data

# %%
from pathlib import Path
import tarfile
import urllib.request

def load_housing_data():
    tarball_path = Path("datasets/housing.tgz")
    if not tarball_path.is_file():
        Path("datasets").mkdir(parents=True, exist_ok=True)
        url = "https://github.com/ageron/data/raw/main/housing.tgz"
        urllib.request.urlretrieve(url, tarball_path)
        with tarfile.open(tarball_path) as housing_tarball:
            housing_tarball.extractall(path="datasets")
    return pd.read_csv(Path("datasets/housing/housing.csv"))

housing = load_housing_data()

# %% [markdown]
# ## Inspecting the data

# %%
housing.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %% [markdown]
# `ocean_proximity` is the only column that is not numeric. Let's look at its values

# %%
housing['ocean_proximity'].value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: count, dtype: int64

# %% [markdown]
# Now, lets get a sense for the numeric values

# %%
housing.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# 25%        296.000000    787.000000    280.000000       2.563400
# 50%        435.000000   1166.000000    409.000000       3.534800
# 75%        647.000000   1725.000000    605.000000       4.743250
# max       6445.000000  35682.000000   6082.000000      15.000100
#
#        median_house_value
# count        20640.000000
# mean        206855.816909
# std         115395.615874
# min          14999.000000
# 25%         119600.000000
# 50%         179700.000000
# 75%         264725.000000
# max         500001.000000

# %% [markdown]
# The `min` row is suspicious, it looks like there might be at least a district with invalid data, 3 people in a district does not make sense

# %%
housing.hist(bins=50, figsize=(15,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %% [markdown]
# ### Some initial observations
# * Some attributes are preprocessed:
#   * `median_income` has been scaled and capped between 0.4999 and 15.0001
#   * `median_hose_value` has been capped to 500000, which explains the spike, and might be a problem because it is the target attribute
#   * `housing_median_age` has been capped
# * The attributes have different scales
# * Many of the histograms are skewed right

# %% [markdown]
# ## Train / Test sets

# %% [markdown]
# Define a function to shuffle the housing data and split it into two sets according to the specified ratio

# %%
def shuffle_and_split_data(data, test_ratio):
    shuffled_indeces = np.random.permutation(len(data))
    test_set_size = int(len(data) * test_ratio)
    test_indeces = shuffled_indeces[:test_set_size]
    train_indeces = shuffled_indeces[test_set_size:]
    return data.iloc[train_indeces], data.iloc[test_indeces]

train_set, test_set = shuffle_and_split_data(housing, 0.2)

print(housing.shape)
print(test_set.shape)
print(train_set.shape)
train_set.head()
# Out:
# (20640, 10)
# (4128, 10)
# (16512, 10)
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 19735    -117.60     34.02                16.0       2103.0           348.0
# 11179    -118.96     36.66                18.0       1302.0           424.0
# 7905     -120.74     39.39                18.0        453.0           117.0
# 12664    -122.56     38.03                34.0       1887.0           290.0
# 19665    -121.91     37.24                24.0       5046.0          1001.0
#
#        population  households  median_income  median_house_value  \
# 19735      1305.0       356.0         5.2849            160400.0
# 11179       320.0       133.0         3.1964             80000.0
# 7905        152.0        77.0         1.3523             85700.0
# 12664       815.0       283.0         6.5249            324800.0
# 19665      2449.0       968.0         4.7118            274600.0
#
#       ocean_proximity
# 19735          INLAND
# 11179          INLAND
# 7905           INLAND
# 12664        NEAR BAY
# 19665       <1H OCEAN

# %% [markdown]
# The downside of this approach is that it is not deterministic, and the split will change for each execution.
#
# A solution to this problem is to set the randomness seed, so that we get the same results each time:

# %%
def shuffle_and_split_data(data, test_ratio):
    np.random.seed(42)
    
    shuffled_indeces = np.random.permutation(len(data))
    test_set_size = int(len(data) * test_ratio)
    test_indeces = shuffled_indeces[:test_set_size]
    train_indeces = shuffled_indeces[test_set_size:]
    return data.iloc[train_indeces], data.iloc[test_indeces]

# %%
train_set, test_set = shuffle_and_split_data(housing, 0.2)
train_set.head()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 14196    -117.22     32.75                34.0       6001.0          1111.0
# 8267     -117.03     32.69                10.0        901.0           163.0
# 17445    -122.27     37.74                28.0       6909.0          1554.0
# 14265    -121.82     37.25                25.0       4021.0           634.0
# 2271     -115.98     33.32                 8.0        240.0            46.0
#
#        population  households  median_income  median_house_value  \
# 14196      2654.0      1072.0         4.5878            291000.0
# 8267        698.0       167.0         4.6648            156100.0
# 17445      2974.0      1484.0         3.6875            353900.0
# 14265      2178.0       650.0         5.1663            241200.0
# 2271         63.0        24.0         1.4688             53800.0
#
#       ocean_proximity
# 14196      NEAR OCEAN
# 8267       NEAR OCEAN
# 17445        NEAR BAY
# 14265       <1H OCEAN
# 2271           INLAND

# %%
train_set, test_set = shuffle_and_split_data(housing, 0.2)
train_set.head()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 14196    -117.22     32.75                34.0       6001.0          1111.0
# 8267     -117.03     32.69                10.0        901.0           163.0
# 17445    -122.27     37.74                28.0       6909.0          1554.0
# 14265    -121.82     37.25                25.0       4021.0           634.0
# 2271     -115.98     33.32                 8.0        240.0            46.0
#
#        population  households  median_income  median_house_value  \
# 14196      2654.0      1072.0         4.5878            291000.0
# 8267        698.0       167.0         4.6648            156100.0
# 17445      2974.0      1484.0         3.6875            353900.0
# 14265      2178.0       650.0         5.1663            241200.0
# 2271         63.0        24.0         1.4688             53800.0
#
#       ocean_proximity
# 14196      NEAR OCEAN
# 8267       NEAR OCEAN
# 17445        NEAR BAY
# 14265       <1H OCEAN
# 2271           INLAND

# %% [markdown]
# Now the splits are deterministic.
#
# However, there's another issue with this approach to splitting data. If the data gets updated by adding new samples to the dataset, our inputs will again be shuffled in a different way, so the train and test sets items will not persist. It would be better if only the new samples in the dataset get shuffled and added to our current train and test sets.
#
# To achieve this, we could assing an id to each sample, and use this id to generate a random value to be used to split the data. A good candidate for id would be `longitude + latitude` since the combination of those fields will not change if the dataset is updated, and the value should not be repeated.

# %%
from zlib import crc32

def is_id_in_test_set(identifier, test_ratio):
    return crc32(np.int64(identifier)) < test_ratio * 2**32

def split_data_with_id_hash(data, test_ratio, id_column):
    ids = data[id_column]
    is_in_test_set = ids.apply(lambda id_: is_id_in_test_set(id_, test_ratio))

    return data[~is_in_test_set], data[is_in_test_set]

# %%
housing['id'] = housing['longitude'] * 100000 + housing['latitude']

train_set, test_set = split_data_with_id_hash(housing, 0.2, 'id')
print(housing.shape)
print(test_set.shape)
print(train_set.shape)

train_set.head()
# Out:
# (20640, 11)
# (3967, 11)
# (16673, 11)
#     longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0     -122.23     37.88                41.0        880.0           129.0
# 1     -122.22     37.86                21.0       7099.0          1106.0
# 2     -122.24     37.85                52.0       1467.0           190.0
# 8     -122.26     37.84                42.0       2555.0           665.0
# 10    -122.26     37.85                52.0       2202.0           434.0
#
#     population  households  median_income  median_house_value ocean_proximity  \
# 0        322.0       126.0         8.3252            452600.0        NEAR BAY
# 1       2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2        496.0       177.0         7.2574            352100.0        NEAR BAY
# 8       1206.0       595.0         2.0804            226700.0        NEAR BAY
# 10       910.0       402.0         3.2031            281500.0        NEAR BAY
#
#              id
# 0  -12222962.12
# 1  -12221962.14
# 2  -12223962.15
# 8  -12225962.16
# 10 -12225962.15

# %% [markdown]
# Now any new sample will be included in the test or training set deterministically and according to the specified ratio for test data.
#
# Something to note is that the split has not been 80% - 20% exactly, that happens because we are relying on the probability of the generated crc32 code to be less than the value in the lower 20% of all possible values. The more samples we have the more we will approach to the specified ratio.

# %% [markdown]
# ### Avoiding sampling bias
#
# We are told that the `median_income` attribute is very important to predict the `median_housing_price`, so we want to ensure that the test set is representative of the different values that `median_income` can take. Since the attribute is continuous, we will have to make categories out of it.
#
# Lets look at the values again:

# %%
housing['median_income'].hist(bins=50)
# Out:
# <Axes: >

# %% [markdown]
# Most median income values are between 1.5 and 6. We will divide the values into categories to ensure that each category is large enough to be representative

# %%
housing['income_cat'] = pd.cut(housing['median_income'],
                               bins=[0.0, 1.5, 3.0, 4.5, 6.0, np.inf],
                               labels=[1, 2, 3, 4, 5])

# %%
housing['income_cat'].value_counts().sort_index().plot.bar(rot=0)
plt.xlabel('Income category')
plt.ylabel('Number of districts')
plt.show()

# %%
from sklearn.model_selection import train_test_split
strat_train_set, strat_test_set = train_test_split(housing, test_size=0.2, stratify=housing['income_cat'], random_state=42)

# %% [markdown]
# Comparison of the % of samples in each income category between the whole dataset, the stratified split and the non stratified split:

# %%
housing['income_cat'].value_counts() / len(housing)
# Out:
# income_cat
# 3    0.350581
# 2    0.318847
# 4    0.176308
# 5    0.114438
# 1    0.039826
# Name: count, dtype: float64

# %%
strat_test_set['income_cat'].value_counts() / len(strat_test_set)
# Out:
# income_cat
# 3    0.350533
# 2    0.318798
# 4    0.176357
# 5    0.114341
# 1    0.039971
# Name: count, dtype: float64

# %%
non_strat_train_set, non_strat_test_set = train_test_split(housing, test_size=0.2, random_state=42)
non_strat_test_set['income_cat'].value_counts() / len(non_strat_test_set)
# Out:
# income_cat
# 3    0.345203
# 2    0.307413
# 4    0.184109
# 5    0.120882
# 1    0.042393
# Name: count, dtype: float64

# %% [markdown]
# The percentages in the whole data and the stratified test set are almost the same

# %% [markdown]
# Delete the `income_cat` attribute, as it will no longer be used

# %%
strat_train_set.drop('income_cat', axis=1, inplace=True)
strat_test_set.drop('income_cat', axis=1, inplace=True)

# %% [markdown]
# ## Exploring and visualizing data

# %% [markdown]
# First, hide the test set and make a copy of the training dataset to experiment with it.

# %%
housing = strat_train_set.copy()

# %% [markdown]
# ### Visualizing geographical data

# %%
housing.plot(kind='scatter', x='longitude', y='latitude', grid=True, alpha=0.2)
plt.show()

# %% [markdown]
# The alpha parameter helps visualize high density areas

# %%
s_scaling = 200/housing['population'].max()
housing.plot(kind='scatter', x='longitude', y='latitude', grid=True,
             s=housing['population']*s_scaling, label='population',
             c='median_house_value', cmap='jet', colorbar=True,
             legend=True, sharex=False, figsize=(10,7))
plt.show()

# %% [markdown]
# ### Look for correlations

# %%
housing.drop('ocean_proximity', axis=1, inplace=True)

corr_matrix = housing.corr()
corr_matrix['median_house_value'].sort_values(ascending=False)
# Out:
# median_house_value    1.000000
# median_income         0.688380
# rooms_per_house       0.143663
# total_rooms           0.137455
# housing_median_age    0.102175
# households            0.071426
# total_bedrooms        0.054635
# population           -0.020153
# pople_per_house      -0.038224
# longitude            -0.050859
# id                   -0.050861
# latitude             -0.139584
# bedrooms_ratio       -0.256397
# Name: median_house_value, dtype: float64

# %% [markdown]
# There is a correlation between `median_income` and `median_house_value`. It looks like this attribute will contribute more than others to the prediction of the house values.

# %%
from pandas.plotting import scatter_matrix

attributes = ['median_house_value', 'median_income', 'total_rooms', 'housing_median_age']
scatter_matrix(housing[attributes], figsize=(12, 8))
plt.show()

# %% [markdown]
# Again, it looks like the most promising attribute is `median_income`

# %%
housing.plot(kind='scatter', x='median_income', y='median_house_value', alpha=0.1, grid=True)
plt.show()

# %% [markdown]
# ### Combining attributes

# %%
housing['rooms_per_house'] = housing['total_rooms'] / housing['households']
housing['bedrooms_ratio'] = housing['total_bedrooms'] / housing['total_rooms']
housing['pople_per_house'] = housing['population'] / housing['households']

corr_matrix = housing.corr()

corr_matrix['median_house_value'].sort_values(ascending=False)
# Out:
# median_house_value    1.000000
# median_income         0.688380
# rooms_per_house       0.143663
# total_rooms           0.137455
# housing_median_age    0.102175
# households            0.071426
# total_bedrooms        0.054635
# population           -0.020153
# pople_per_house      -0.038224
# longitude            -0.050859
# id                   -0.050861
# latitude             -0.139584
# bedrooms_ratio       -0.256397
# Name: median_house_value, dtype: float64

# %% [markdown]
# `bedrooms_ratio` shows a negative correlation, and `rooms_per_house` a positive but not as strong correlation

# %% [markdown]
# ## Preparing the data for machine learning algorithms

# %% [markdown]
# Undo changes to the training data and split predictors and labels

# %%
housing = strat_train_set.drop('median_house_value', axis=1)
housing_labels = strat_train_set['median_house_value'].copy()

# %% [markdown]
# ### Clean the data

# %%
# Checking for missing values
housing.isna().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        168
# population              0
# households              0
# median_income           0
# ocean_proximity         0
# id                      0
# dtype: int64

# %% [markdown]
# To deal with the missing data in `total_bedrooms` the missing values we could:
# - delete the rows with missing values
# - delete the attribute with missing values
# - set the missing values to some reasonable value
#
# In this case the missing values will be replaced with the median value.
# For this the Scikit-Learn `SimpleImputer` class will be used. This will also help for other attributes if there is missing data in the test data or when the system goes live.

# %%
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(strategy='median')

housing_num = housing.select_dtypes(include=[np.number])

imputer.fit(housing_num)
# Out:
# SimpleImputer(strategy='median')

# %%
imputer.statistics_
# Out:
# array([-1.18510000e+02,  3.42600000e+01,  2.90000000e+01,  2.12500000e+03,
#         4.34000000e+02,  1.16700000e+03,  4.08000000e+02,  3.53850000e+00,
#        -1.18509658e+07])

# %% [markdown]
# The values calculated by the imputer ar the median values:

# %%
housing_num.median().values
# Out:
# array([-1.18510000e+02,  3.42600000e+01,  2.90000000e+01,  2.12500000e+03,
#         4.34000000e+02,  1.16700000e+03,  4.08000000e+02,  3.53850000e+00,
#        -1.18509658e+07])

# %% [markdown]
# Transform the missing values

# %%
X = imputer.transform(housing_num)

housing_tr = pd.DataFrame(X, columns=housing_num.columns, index=housing_num.index)

# %%
housing_tr.isna().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# id                    0
# dtype: int64

# %%
housing_tr[housing['total_bedrooms'].isna()]['total_bedrooms']
# Out:
# 14452    434.0
# 18217    434.0
# 11889    434.0
# 20325    434.0
# 14360    434.0
#          ...
# 2348     434.0
# 366      434.0
# 18241    434.0
# 18493    434.0
# 16519    434.0
# Name: total_bedrooms, Length: 168, dtype: float64

# %% [markdown]
# All the missing values were set to `434` which is the median

# %% [markdown]
# ## Handling text and categorical attributes
#
# The only non numeric attribute in this dataset is `ocean_proximity`. Its values are not arbitrary, there are 5 different values, so the attribute is categorical.

# %%
housing_cat = housing[['ocean_proximity']]
housing_cat.head(8)
# Out:
#       ocean_proximity
# 13096        NEAR BAY
# 14973       <1H OCEAN
# 3785           INLAND
# 14689          INLAND
# 20507      NEAR OCEAN
# 1286           INLAND
# 18078       <1H OCEAN
# 4396         NEAR BAY

# %%
housing_cat.value_counts()
# Out:
# ocean_proximity
# <1H OCEAN          7274
# INLAND             5301
# NEAR OCEAN         2089
# NEAR BAY           1846
# ISLAND                2
# Name: count, dtype: int64

# %% [markdown]
# One way to encode this values numerically is by assigning different consecutive whole numbers to each different value, in this case 0, 1, 2, 3, 4.

# %%
from sklearn.preprocessing import OrdinalEncoder

ordinal_encoder = OrdinalEncoder()
housing_cat_encoded =ordinal_encoder.fit_transform(housing_cat)

housing_cat_encoded[:8]
# Out:
# array([[3.],
#        [0.],
#        [1.],
#        [1.],
#        [4.],
#        [1.],
#        [0.],
#        [3.]])

# %%
ordinal_encoder.categories_
# Out:
# [array(['<1H OCEAN', 'INLAND', 'ISLAND', 'NEAR BAY', 'NEAR OCEAN'],
#        dtype=object)]

# %% [markdown]
# The problem with this representation is that having different values implicitly tells the ML algorithms that there is a relation between the values so an value of 1 would be assumed to be similar to 2 and less similar to 4.
#
# In this case we do not want that. So a different encoding can be used in these cases: One-hot encoding

# %%
from sklearn.preprocessing import OneHotEncoder

cat_encoder = OneHotEncoder()
housing_cat_1hot = cat_encoder.fit_transform(housing_cat)

housing_cat_1hot
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 16512 stored elements and shape (16512, 5)>

# %%
cat_encoder.categories_
# Out:
# [array(['<1H OCEAN', 'INLAND', 'ISLAND', 'NEAR BAY', 'NEAR OCEAN'],
#        dtype=object)]

# %% [markdown]
# Another way to achive a similar resul is with pandas `get_dummies`. But the `OneHotEncoder` is better because it remembers the categories it was trained on, its output shape will stay the same even if less values are transformed.

# %%
# example
df_test = pd.DataFrame({'ocean_proximity': ['INLAND', 'NEAR BAY']})
enc = pd.get_dummies(df_test)

print(enc.shape)
enc
# Out:
# (2, 2)
#    ocean_proximity_INLAND  ocean_proximity_NEAR BAY
# 0                    True                     False
# 1                   False                      True

# %%
enc = cat_encoder.transform(df_test).toarray()

print(enc.shape)
enc
# Out:
# (2, 5)
# array([[0., 1., 0., 0., 0.],
#        [0., 0., 0., 1., 0.]])

# %% [markdown]
# ## Feature Scaling and Transformation

# %% [markdown]
# Min-max scaling (normalization): $x_i \leftarrow (MAX-MIN) \frac{x_i - x_{min}}{x_{max} - x_{min}} + MIN$

# %%
from sklearn.preprocessing import MinMaxScaler

min_max_scaler = MinMaxScaler(feature_range=(-1, 1))
housing_num_min_max_scaled = min_max_scaler.fit_transform(housing_num)
housing_num_min_max_scaled.T[:,0]
# Out:
# array([-0.60851927,  0.11702128,  1.        , -0.83117147, -0.64116605,
#        -0.80701754, -0.61433638, -0.7794789 , -0.60852222])

# %%
# compare normalized longitude with normalization using the formula
min_ = -1
max_ = 1
a = max_ - min_
x_min = housing_num['longitude'].min()
x_max = housing_num['longitude'].max()
normalized = a * (housing_num['longitude'] - x_min)/(x_max - x_min) + min_

print("Equal" if np.sum(housing_num_min_max_scaled[:,0] - normalized > 0.0001) == 0 else "NOT Equal")
# Out:
# Equal

# %% [markdown]
# Standarization is less affected by outliers, but the range of values is not restricted. Standarized values will have a 0 mean.
#
# Standarization: $x_i \leftarrow \frac{x_i - \mu}{\sigma}$

# %%
from sklearn.preprocessing import StandardScaler

std_scaler = StandardScaler()
housing_num_std_scaled = std_scaler.fit_transform(housing_num)
housing_num_std_scaled[:,0]
# Out:
# array([-1.42303652,  0.59639445, -1.2030985 , ...,  1.25620853,
#         0.58639727, -1.41803793], shape=(16512,))

# %%
# compare standarized longitude with standarization using the formula
mean = housing_num['longitude'].mean()
std = housing_num['longitude'].std()

standarized = (housing_num['longitude'] - mean)/std
print("Equal" if np.sum(housing_num_std_scaled[:,0] - standarized > 0.0001) == 0 else "NOT Equal")
# Out:
# Equal

# %% [markdown]
# Before normalizing or standarizing the values, it is useful to deal with heavy tails in the distribution of the values.
# Some ways of doing this are to raise to a power between 0 and 1, or to take to log of the values

# %%
fig, axes = plt.subplots(1, 2, figsize=(8,3), sharey=True)
fig.suptitle('Shinking heavy tail')
fig.supylabel('Number of districts')
axes[0].hist(housing['population'], bins=50)
axes[0].set_xlabel('Population')
axes[0].grid(True)

population_log = np.log(housing['population'])
axes[1].hist(population_log, bins=50)
axes[1].set_xlabel('Log of opulation')
axes[1].grid(True)

fig.tight_layout()
fig.show()
